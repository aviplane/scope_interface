# %%
rm = pyvisa.ResourceManager()
res = rm.list_resources()
print(res)
# Out:
# ('USB0::0x1AB1::0x04CE::DS1ZA205020654::INSTR', 'USB0::0x1AB1::0x04CE::DS1ZA164256910::INSTR', 'USB0::0x1AB1::0x04CE::DS1ZA205020656::INSTR', 'TCPIP0::10.64.56.30::inst0::INSTR', 'TCPIP0::10.64.56.30::hislip0::INSTR', 'ASRL1::INSTR', 'ASRL3::INSTR')

# %%
import pyvisa
import time
rm = pyvisa.ResourceManager()
res = rm.list_resources()
print(res)
# Out:
# ('USB0::0x1AB1::0x04CE::DS1ZA205020654::INSTR', 'USB0::0x1AB1::0x04CE::DS1ZA164256910::INSTR', 'USB0::0x1AB1::0x04CE::DS1ZA205020656::INSTR', 'TCPIP0::10.64.56.30::inst0::INSTR', 'TCPIP0::10.64.56.30::hislip0::INSTR', 'ASRL1::INSTR', 'ASRL3::INSTR')

# %%
inst_id = "DS1ZA205020656"
index = [i for i in range(len(res)) if inst_id in res[i]]
print(index)
# Out:
# [2]

# %%
inst = rm.open_resource(res[index[0]])

# %%
inst.query("*IDN?")
# Out:
# 'RIGOL TECHNOLOGIES,DS1104Z,DS1ZA205020656,00.04.04.SP3\n'

# %%
t_scale = inst.query_ascii_values(":TIM:SCAL?")
v_scale = inst.query_ascii_values(":CHAN1:SCAL?")
v_offset = inst.query_ascii_values(":CHAN1:OFFS?")
t_scale, v_scale, v_offset
inst.query_ascii_values(":TIM:OFFS?")
# Out:
# [0.0]

# %%
import matplotlib.pyplot as plt
import numpy as np

inst.write(":TIM:SCAL 0.02")
inst.write(":TIM:OFFS 0")

time.sleep(1)
for i in range(1):
    inst.write(":STOP")
    inst.write(':WAV:SOUR CHAN1')
    inst.write(':WAV:MODE norm')
    inst.write(':WAV:FORM byte')
    # inst.write(':WAV:STAR 1')
    # inst.write(':WAV:stop 10000')
    inst.write(":WAV:DATA?")
    data = inst.read_raw()
    wvf_format, wvf_type, wvf_points, count, xinc, xorigin, xref, yinc, yorigin, yref = inst.query_ascii_values(":WAV:PRE?")
    data = np.frombuffer(data, dtype = "uint8",offset = 12)[:-1]
    print(len(data))
    inst.write(":RUN")
# Out:
# 1199

# %%
fig, ax = plt.subplots()
print(xinc, xorigin, xref)
t = np.arange(0, wvf_points * xinc, xinc) + xorigin
t = t[:-1]
ax.plot(t, (data - yref) * yinc - yorigin)
# Out:
# 0.0002 -0.12 0.0

# %%
len(np.arange(0, 0.1 * 10, 0.1))
# Out:
# 10

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(data)
